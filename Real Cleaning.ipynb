# %%
import pandas as pd
import missingno as msno
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
from haversine import haversine, Unit

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
df_all_housing_info = pd.read_csv('data/eda.csv')
df_all_housing_info
# Out:
#                id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520       3.0       1.00       1180.0    5650.0     1.0
# 1      6414100192       3.0       2.25       2570.0    7242.0     2.0
# 2      5631500400       2.0       1.00        770.0   10000.0     1.0
# 3      2487200875       4.0       3.00       1960.0    5000.0     1.0
# 4      1954400510       3.0       2.00       1680.0    8080.0     1.0
# ...           ...       ...        ...          ...       ...     ...
# 21592   263000018       3.0       2.50       1530.0    1131.0     3.0
# 21593  6600060120       4.0       2.50       2310.0    5813.0     2.0
# 21594  1523300141       2.0       0.75       1020.0    1350.0     2.0
# 21595   291310100       3.0       2.50       1600.0    2388.0     2.0
# 21596  1523300157       2.0       0.75       1020.0    1076.0     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df_all_housing_info.sort_values("bedrooms").head(1)
# Out:
#               id  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 2971  3278602670       1.0        1.0        820.0    1060.0     1.0
#
#       waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 2971         0.0   0.0          3      8       760.0           60.0      2007
#
#       yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15  \
# 2971           NaN    98126  47.5473 -122.371         1770.0      1924.0
#
#             date     price
# 2971  2014-09-30  219500.0

# %%
df_all_housing_info.bathrooms.unique()
print(df_all_housing_info.query('sqft_living %1 !=0').shape,
df_all_housing_info.query('sqft_lot %1 !=0').shape,
df_all_housing_info.query('floors %1 !=0 ').shape,
df_all_housing_info.query('waterfront %1 !=0').shape,
df_all_housing_info.query('view %1 !=0').shape
)
# Out:
# (0, 21) (0, 21) (2078, 21) (2391, 21) (63, 21)

# %%
df_all_housing_info[['condition','grade']].isna().sum()
# Out:
# condition    0
# grade        0
# dtype: int64

# %% [markdown]
# * bedrooms can be made to int (no comma values)
# * bathrooms have comma values
